# %%
from chess_evaluator import evaluate_board, piece_values
import chess
import random

# %%
def score_move(board, move):
    """
    Scores moves based on heuristics to improve move ordering.
    Higher scores indicate better moves.
    """
    score = 0

    # Prioritize captures using MVV-LVA (Most Valuable Victim - Least Valuable Attacker)
    if board.is_capture(move):
        captured_piece = board.piece_at(move.to_square)
        if captured_piece:
            attacker = board.piece_at(move.from_square)
            score += 10 * piece_values[captured_piece.piece_type] - piece_values[attacker.piece_type]

    # Prioritize promotions
    if move.promotion:
        score += 800  # High score for promotions

    # Prioritize checks
    board.push(move)
    if board.is_check():
        score += 50
    board.pop()

    # Penalize moves that hang a piece
    board.push(move)
    if board.is_attacked_by(not board.turn, move.to_square):
        if not board.is_attacked_by(board.turn, move.to_square):
            # The piece is hanging
            score -= piece_values[board.piece_type_at(move.to_square)]
    board.pop()

    return score

# %%
killer_moves = {}

def minimax(board, depth, alpha, beta, maximizing_player):
    if depth == 0 or board.is_game_over():
        return evaluate_board(board)

    global killer_moves
    killer_move = killer_moves.get(depth)

    if maximizing_player:
        max_eval = -float('inf')
        moves = list(board.legal_moves)

        # Place the killer move at the front if it exists
        if killer_move in moves:
            moves.remove(killer_move)
            moves.insert(0, killer_move)

        moves.sort(key=lambda move: score_move(board, move), reverse=True)

        for move in moves:
            board.push(move)
            eval = minimax(board, depth - 1, alpha, beta, False)
            board.pop()
            if eval > max_eval:
                max_eval = eval
                if eval > alpha:
                    alpha = eval
                    # Update killer move
                    killer_moves[depth] = move
            if beta <= alpha:
                break  # Beta cutoff
        return max_eval
    else:
        min_eval = float('inf')
        moves = list(board.legal_moves)

        # Place the killer move at the front if it exists
        if killer_move in moves:
            moves.remove(killer_move)
            moves.insert(0, killer_move)

        moves.sort(key=lambda move: score_move(board, move), reverse=True)

        for move in moves:
            board.push(move)
            eval = minimax(board, depth - 1, alpha, beta, True)
            board.pop()
            if eval < min_eval:
                min_eval = eval
                if eval < beta:
                    beta = eval
                    # Update killer move
                    killer_moves[depth] = move
            if beta <= alpha:
                break  # Alpha cutoff
        return min_eval

# %%
def select_best_move(board, depth):
    best_move = None
    max_eval = -float('inf')
    alpha = -float('inf')
    beta = float('inf')

    moves = list(board.legal_moves)
    moves.sort(key=lambda move: score_move(board, move), reverse=True)

    for move in moves:
        board.push(move)
        eval = minimax(board, depth - 1, alpha, beta, False)
        board.pop()
        if eval > max_eval:
            max_eval = eval
            best_move = move
        alpha = max(alpha, eval)
    return best_move

# %%
def play_game():
    board = chess.Board()
    depth = 3  # Set the desired depth

    while not board.is_game_over():
        if board.turn == chess.WHITE:
            # Bot's move
            move = select_best_move(board, depth)
        else:
            # For testing, opponent makes a random move
            move = random.choice(list(board.legal_moves))
        board.push(move)
        print(board)
        print(f"Evaluation: {evaluate_board(board)}\n")

# %%
play_game()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 play_game()
#
# Cell In[29], line 8, in play_game()
#       5 while not board.is_game_over():
#       6     if board.turn == chess.WHITE:
#       7         # Bot's move
# ----> 8         move = select_best_move(board, depth)
#       9     else:
#      10         # For testing, opponent makes a random move
#      11         move = random.choice(list(board.legal_moves))
#
# Cell In[28], line 12, in select_best_move(board, depth)
#      10 for move in moves:
#      11     board.push(move)
# ---> 12     eval = minimax(board, depth - 1, alpha, beta, False)
#      13     board.pop()
#      14     if eval > max_eval:
#
# Cell In[27], line 47, in minimax(board, depth, alpha, beta, maximizing_player)
#      45 for move in moves:
#      46     board.push(move)
# ---> 47     eval = minimax(board, depth - 1, alpha, beta, True)
#      48     board.pop()
#      49     if eval < min_eval:
#
# Cell In[27], line 23, in minimax(board, depth, alpha, beta, maximizing_player)
#      21 for move in moves:
#      22     board.push(move)
# ---> 23     eval = minimax(board, depth - 1, alpha, beta, False)
#      24     board.pop()
#      25     if eval > max_eval:
#
# Cell In[27], line 5, in minimax(board, depth, alpha, beta, maximizing_player)
#       3 def minimax(board, depth, alpha, beta, maximizing_player):
#       4     if depth == 0 or board.is_game_over():
# ----> 5         return evaluate_board(board)
#       7     global killer_moves
#       8     killer_move = killer_moves.get(depth)
#
# File ~/UiS/DNN/CHESS/chess_evaluator.py:1122, in evaluate_board(board)
#    1120 evaluation += evaluate_rooks(board)
#    1121 evaluation += evaluate_queens(board)
# -> 1122 evaluation += evaluate_king(board)  # Includes enhanced king safety
#    1124 # Global features
#    1125 evaluation += evaluate_mobility(board)
#
# File ~/UiS/DNN/CHESS/chess_evaluator.py:1089, in evaluate_king(board)
#    1087         evaluation += factor * king_table_midgame[chess.square_mirror(king_square)]
#    1088     # King safety
# -> 1089     evaluation += king_safety(board, is_white)
#    1090 else:
#    1091     # Use endgame table and king activity evaluation
#    1092     if is_white:
#
# File ~/UiS/DNN/CHESS/chess_evaluator.py:1010, in king_safety(board, is_white)
#    1007 evaluation += factor * open_line_penalty
#    1009 # 3. Enemy Attackers Near the King
# -> 1010 attackers_penalty = evaluate_attackers_near_king(board, king_square, is_white, game_phase)
#    1011 evaluation += factor * attackers_penalty
#    1013 # 4. Weak Squares Around the King
#
# File ~/UiS/DNN/CHESS/chess_evaluator.py:929, in evaluate_attackers_near_king(board, king_square, is_white, game_phase)
#     927 attackers = 0
#     928 attack_value = 10 if game_phase == 'middlegame' else 5
# --> 929 squares_around_king = chess.SquareSet(chess.square_ring(king_square, 1))
#     931 for piece_type in [chess.QUEEN, chess.ROOK, chess.BISHOP, chess.KNIGHT]:
#     932     enemy_pieces = board.pieces(piece_type, enemy_color)
#
# AttributeError: module 'chess' has no attribute 'square_ring'
